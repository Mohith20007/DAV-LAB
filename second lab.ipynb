# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\user\ecommerce_sales_customer_analytics_150k.csv")
print(df)
# Out:
#           order_id  order_date order_time order_status sales_channel  \
# 0       ORD-301242  2023-11-06   16:37:47    Completed    Mobile App
# 1       ORD-773460  2025-12-24   01:22:36    Completed       Website
# 2       ORD-449374  2021-07-05   14:24:21    Completed    Mobile App
# 3       ORD-567636  2023-01-21   07:20:26    Completed  Social Media
# 4       ORD-820028  2022-05-13   09:46:21    Completed  Social Media
# ...            ...         ...        ...          ...           ...
# 138111  ORD-481534  2025-09-27   13:00:50    Completed    Mobile App
# 138112  ORD-487614  2023-07-22   09:13:25     Returned  Social Media
# 138113  ORD-248062  2025-09-08   18:30:32    Cancelled    Mobile App
# 138114  ORD-252033  2022-04-06   14:50:07    Completed  Social Media
# 138115  ORD-528577  2022-11-23   11:46:00    Completed    Mobile App
#
#         customer_id     customer_name  customer_age  gender customer_segment  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 138116 entries, 0 to 138115
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  138116 non-null  str
#  1   order_date                138116 non-null  str
#  2   order_time                138116 non-null  str
#  3   order_status              138116 non-null  str
#  4   sales_channel             138116 non-null  str
#  5   customer_id               138116 non-null  str
#  6   customer_name             138116 non-null  str
#  7   customer_age              138116 non-null  int64
#  8   gender                    138116 non-null  str
#  9   customer_segment          138116 non-null  str
#  10  customer_type             138116 non-null  str
#  11  customer_city             138116 non-null  str
#  12  customer_state            138116 non-null  str
#  13  customer_country          138116 non-null  str
# ...

# %%
print(df.columns)
# Out:
# Index(['order_id', 'order_date', 'order_time', 'order_status', 'sales_channel',
#        'customer_id', 'customer_name', 'customer_age', 'gender',
#        'customer_segment', 'customer_type', 'customer_city', 'customer_state',
#        'customer_country', 'region', 'customer_postal_code', 'payment_method',
#        'payment_status', 'currency', 'shipping_method', 'warehouse',
#        'delivery_days', 'estimated_delivery_days', 'delivery_status',
#        'return_status', 'return_reason', 'customer_rating', 'review_sentiment',
#        'customer_review', 'marketing_channel', 'campaign_name', 'coupon_code',
#        'loyalty_points_earned', 'loyalty_points_redeemed', 'quantity',
#        'gross_sales', 'discount_amount', 'tax_amount', 'shipping_cost',
#        'net_sales', 'product_cost', 'profit', 'profit_margin_percentage',
#        'customer_lifetime_value', 'is_repeat_customer',
#        'customer_order_count'],
#       dtype='str')

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of           order_id  order_date order_time order_status sales_channel  \
# 0       ORD-301242  2023-11-06   16:37:47    Completed    Mobile App
# 1       ORD-773460  2025-12-24   01:22:36    Completed       Website
# 2       ORD-449374  2021-07-05   14:24:21    Completed    Mobile App
# 3       ORD-567636  2023-01-21   07:20:26    Completed  Social Media
# 4       ORD-820028  2022-05-13   09:46:21    Completed  Social Media
# ...            ...         ...        ...          ...           ...
# 138111  ORD-481534  2025-09-27   13:00:50    Completed    Mobile App
# 138112  ORD-487614  2023-07-22   09:13:25     Returned  Social Media
# 138113  ORD-248062  2025-09-08   18:30:32    Cancelled    Mobile App
# 138114  ORD-252033  2022-04-06   14:50:07    Completed  Social Media
# 138115  ORD-528577  2022-11-23   11:46:00    Completed    Mobile App
#
#         customer_id     customer_name  customer_age  gender customer_segment  \
# ...

# %%
print(df["customer_age"].mean())
# Out:
# 45.86268064525471

# %%
print(df["customer_age"].median())
# Out:
# 46.0

# %%
print(df["customer_age"].mode())
# Out:
# 0    19
# Name: customer_age, dtype: int64

# %%
print(df["customer_age"].var())
# Out:
# 271.18434348997505

# %%
print(df["customer_age"].std())
# Out:
# 16.467675716080123

# %%
print(df["customer_age"].min())
# Out:
# 18

# %%
print(df["customer_age"].max())
# Out:
# 74

# %%
print(df["customer_age"].count())
# Out:
# 138116

# %%
print(df["tax_amount"].unique())
# Out:
# [ 61.07 320.83  29.79 ... 163.1  384.86 372.37]

# %%
print(df["tax_amount"].nunique())
# Out:
# 43093

# %%
print(df["tax_amount"].value_counts())
# Out:
# tax_amount
# 15.56     23
# 11.06     22
# 6.04      22
# 22.07     21
# 40.86     21
#           ..
# 569.46     1
# 319.30     1
# 163.10     1
# 384.86     1
# 372.37     1
# Name: count, Length: 43093, dtype: int64

# %%
print(df.isnull())
# Out:
#         order_id  order_date  order_time  order_status  sales_channel  \
# 0          False       False       False         False          False
# 1          False       False       False         False          False
# 2          False       False       False         False          False
# 3          False       False       False         False          False
# 4          False       False       False         False          False
# ...          ...         ...         ...           ...            ...
# 138111     False       False       False         False          False
# 138112     False       False       False         False          False
# 138113     False       False       False         False          False
# 138114     False       False       False         False          False
# 138115     False       False       False         False          False
#
#         customer_id  customer_name  customer_age  gender  customer_segment  \
# ...

# %%
print(df.isnull().sum())
# Out:
# order_id                         0
# order_date                       0
# order_time                       0
# order_status                     0
# sales_channel                    0
# customer_id                      0
# customer_name                    0
# customer_age                     0
# gender                           0
# customer_segment                 0
# customer_type                    0
# customer_city                    0
# customer_state                   0
# customer_country                 0
# region                           0
# customer_postal_code             0
# payment_method                   0
# payment_status                   0
# currency                         0
# shipping_method                  0
# warehouse                        0
# delivery_days                24557
# estimated_delivery_days      24557
# delivery_status                  0
# return_status               128654
# return_reason               128654
# customer_rating              24557
# ...

# %%
print(df.isnull().mean()*100)
# Out:
# order_id                     0.000000
# order_date                   0.000000
# order_time                   0.000000
# order_status                 0.000000
# sales_channel                0.000000
# customer_id                  0.000000
# customer_name                0.000000
# customer_age                 0.000000
# gender                       0.000000
# customer_segment             0.000000
# customer_type                0.000000
# customer_city                0.000000
# customer_state               0.000000
# customer_country             0.000000
# region                       0.000000
# customer_postal_code         0.000000
# payment_method               0.000000
# payment_status               0.000000
# currency                     0.000000
# shipping_method              0.000000
# warehouse                    0.000000
# delivery_days               17.779982
# estimated_delivery_days     17.779982
# delivery_status              0.000000
# return_status               93.149237
# ...

# %%
print(df.dropna())
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, order_time, order_status, sales_channel, customer_id, customer_name, customer_age, gender, customer_segment, customer_type, customer_city, customer_state, customer_country, region, customer_postal_code, payment_method, payment_status, currency, shipping_method, warehouse, delivery_days, estimated_delivery_days, delivery_status, return_status, return_reason, customer_rating, review_sentiment, customer_review, marketing_channel, campaign_name, coupon_code, loyalty_points_earned, loyalty_points_redeemed, quantity, gross_sales, discount_amount, tax_amount, shipping_cost, net_sales, product_cost, profit, profit_margin_percentage, customer_lifetime_value, is_repeat_customer, customer_order_count]
# Index: []
#
# [0 rows x 46 columns]

# %%
print(df.fillna(0))
# Out:
#           order_id  order_date order_time order_status sales_channel  \
# 0       ORD-301242  2023-11-06   16:37:47    Completed    Mobile App
# 1       ORD-773460  2025-12-24   01:22:36    Completed       Website
# 2       ORD-449374  2021-07-05   14:24:21    Completed    Mobile App
# 3       ORD-567636  2023-01-21   07:20:26    Completed  Social Media
# 4       ORD-820028  2022-05-13   09:46:21    Completed  Social Media
# ...            ...         ...        ...          ...           ...
# 138111  ORD-481534  2025-09-27   13:00:50    Completed    Mobile App
# 138112  ORD-487614  2023-07-22   09:13:25     Returned  Social Media
# 138113  ORD-248062  2025-09-08   18:30:32    Cancelled    Mobile App
# 138114  ORD-252033  2022-04-06   14:50:07    Completed  Social Media
# 138115  ORD-528577  2022-11-23   11:46:00    Completed    Mobile App
#
#         customer_id     customer_name  customer_age  gender customer_segment  \
# ...

# %%
print(df.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 138111    False
# 138112    False
# 138113    False
# 138114    False
# 138115    False
# Length: 138116, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.drop_duplicates())
# Out:
#           order_id  order_date order_time order_status sales_channel  \
# 0       ORD-301242  2023-11-06   16:37:47    Completed    Mobile App
# 1       ORD-773460  2025-12-24   01:22:36    Completed       Website
# 2       ORD-449374  2021-07-05   14:24:21    Completed    Mobile App
# 3       ORD-567636  2023-01-21   07:20:26    Completed  Social Media
# 4       ORD-820028  2022-05-13   09:46:21    Completed  Social Media
# ...            ...         ...        ...          ...           ...
# 138111  ORD-481534  2025-09-27   13:00:50    Completed    Mobile App
# 138112  ORD-487614  2023-07-22   09:13:25     Returned  Social Media
# 138113  ORD-248062  2025-09-08   18:30:32    Cancelled    Mobile App
# 138114  ORD-252033  2022-04-06   14:50:07    Completed  Social Media
# 138115  ORD-528577  2022-11-23   11:46:00    Completed    Mobile App
#
#         customer_id     customer_name  customer_age  gender customer_segment  \
# ...

# %%
print(df[["customer_age","shipping_cost"]])
# Out:
#         customer_age  shipping_cost
# 0                 55          12.03
# 1                 26           9.00
# 2                 69          13.05
# 3                 65          20.85
# 4                 34          23.03
# ...              ...            ...
# 138111            41           6.15
# 138112            40           9.18
# 138113            39          26.94
# 138114            46          84.39
# 138115            28           9.09
#
# [138116 rows x 2 columns]

# %%
print(df.iloc[0:5])
# Out:
#      order_id  order_date order_time order_status sales_channel  customer_id  \
# 0  ORD-301242  2023-11-06   16:37:47    Completed    Mobile App  CUST-003102
# 1  ORD-773460  2025-12-24   01:22:36    Completed       Website  CUST-003124
# 2  ORD-449374  2021-07-05   14:24:21    Completed    Mobile App  CUST-012496
# 3  ORD-567636  2023-01-21   07:20:26    Completed  Social Media  CUST-023928
# 4  ORD-820028  2022-05-13   09:46:21    Completed  Social Media  CUST-012730
#
#     customer_name  customer_age  gender customer_segment  ... discount_amount  \
# 0    Jasmine Ryan            55    Male         Consumer  ...          477.89
# 1     Scott Chase            26    Male          Premium  ...         1456.06
# 2    Marc Wheeler            69  Female          Premium  ...           97.30
# 3  Jennifer Smith            65    Male         Consumer  ...           53.34
# 4    Jessica Wang            34  Female         Consumer  ...          133.63
#
# ...

# %%
print(df[df["customer_age"]>30])
# Out:
#           order_id  order_date order_time order_status sales_channel  \
# 0       ORD-301242  2023-11-06   16:37:47    Completed    Mobile App
# 2       ORD-449374  2021-07-05   14:24:21    Completed    Mobile App
# 3       ORD-567636  2023-01-21   07:20:26    Completed  Social Media
# 4       ORD-820028  2022-05-13   09:46:21    Completed  Social Media
# 5       ORD-208728  2021-02-10   10:05:47      Pending       Website
# ...            ...         ...        ...          ...           ...
# 138110  ORD-874457  2022-11-16   09:38:04    Completed   Marketplace
# 138111  ORD-481534  2025-09-27   13:00:50    Completed    Mobile App
# 138112  ORD-487614  2023-07-22   09:13:25     Returned  Social Media
# 138113  ORD-248062  2025-09-08   18:30:32    Cancelled    Mobile App
# 138114  ORD-252033  2022-04-06   14:50:07    Completed  Social Media
#
#         customer_id      customer_name  customer_age  gender customer_segment  \
# ...

# %%
df.sort_values("customer_age")
# Out:
#           order_id  order_date order_time order_status sales_channel  \
# 40557   ORD-444593  2022-04-25   20:29:33    Completed  Social Media
# 101086  ORD-770616  2024-10-21   07:46:31    Completed   Marketplace
# 83581   ORD-416455  2023-05-04   00:18:15    Completed   Marketplace
# 108843  ORD-264499  2025-03-07   03:43:29      Pending    Mobile App
# 135208  ORD-160998  2021-05-12   18:46:16    Completed       Website
# ...            ...         ...        ...          ...           ...
# 46821   ORD-371204  2022-06-14   19:28:59    Completed   Marketplace
# 83279   ORD-193081  2022-11-06   06:30:06      Pending       Website
# 24364   ORD-649837  2022-12-18   03:40:28    Completed   Marketplace
# 10463   ORD-742841  2023-11-06   12:07:34    Completed       Website
# 125724  ORD-768332  2021-06-03   19:19:15      Pending    Mobile App
#
#         customer_id       customer_name  customer_age      gender  \
# 40557   CUST-016655   Isabella Anderson            18      Female
# ...

# %%
df.rename(columns={"customer_age":"age"})
# Out:
#           order_id  order_date order_time order_status sales_channel  \
# 0       ORD-301242  2023-11-06   16:37:47    Completed    Mobile App
# 1       ORD-773460  2025-12-24   01:22:36    Completed       Website
# 2       ORD-449374  2021-07-05   14:24:21    Completed    Mobile App
# 3       ORD-567636  2023-01-21   07:20:26    Completed  Social Media
# 4       ORD-820028  2022-05-13   09:46:21    Completed  Social Media
# ...            ...         ...        ...          ...           ...
# 138111  ORD-481534  2025-09-27   13:00:50    Completed    Mobile App
# 138112  ORD-487614  2023-07-22   09:13:25     Returned  Social Media
# 138113  ORD-248062  2025-09-08   18:30:32    Cancelled    Mobile App
# 138114  ORD-252033  2022-04-06   14:50:07    Completed  Social Media
# 138115  ORD-528577  2022-11-23   11:46:00    Completed    Mobile App
#
#         customer_id     customer_name  age  gender customer_segment  ...  \
# ...

# %%
df.groupby("customer_id")

# %%
df.head()
# Out:
#      order_id  order_date order_time order_status sales_channel  customer_id  \
# 0  ORD-301242  2023-11-06   16:37:47    Completed    Mobile App  CUST-003102
# 1  ORD-773460  2025-12-24   01:22:36    Completed       Website  CUST-003124
# 2  ORD-449374  2021-07-05   14:24:21    Completed    Mobile App  CUST-012496
# 3  ORD-567636  2023-01-21   07:20:26    Completed  Social Media  CUST-023928
# 4  ORD-820028  2022-05-13   09:46:21    Completed  Social Media  CUST-012730
#
#     customer_name  customer_age  gender customer_segment  ... tax_amount  \
# 0    Jasmine Ryan            55    Male         Consumer  ...      1.203
# 1     Scott Chase            26    Male          Premium  ...      0.900
# 2    Marc Wheeler            69  Female          Premium  ...      1.305
# 3  Jennifer Smith            65    Male         Consumer  ...      2.085
# 4    Jessica Wang            34  Female         Consumer  ...      2.303
#
# ...

# %%
df.tail()
# Out:
#           order_id  order_date order_time order_status sales_channel  \
# 138111  ORD-481534  2025-09-27   13:00:50    Completed    Mobile App
# 138112  ORD-487614  2023-07-22   09:13:25     Returned  Social Media
# 138113  ORD-248062  2025-09-08   18:30:32    Cancelled    Mobile App
# 138114  ORD-252033  2022-04-06   14:50:07    Completed  Social Media
# 138115  ORD-528577  2022-11-23   11:46:00    Completed    Mobile App
#
#         customer_id     customer_name  customer_age  gender customer_segment  \
# 138111  CUST-007151        Donna Ruiz            41  Female         Consumer
# 138112  CUST-006686    Jeremy Aguirre            40    Male          Premium
# 138113  CUST-017497  Timothy Williams            39  Female         Consumer
# 138114  CUST-005723    Charles Hanson            46  Female         Consumer
# 138115  CUST-006809       John Miller            28    Male         Consumer
#
#         ... tax_amount shipping_cost net_sales product_cost   profit  \
# ...

# %%
df.shape
# Out:
# (138116, 47)
